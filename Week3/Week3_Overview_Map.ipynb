# %% [markdown]
# # **Week 3:  Introduction to navigation**

# %% [markdown]
# ```
# Week 3: Introduction to navigation
#  1.1 Previous ROS achievements
#  1.2 New ROS challenge
#
# 2. What is necessary for navigation?
#  2.1 What do we need to navigate?
#  2.2 What do we need to find a treasure?
#  Question 1: Element of Navigation ?
#
# 3. Mapping
#  1. Map of the environment
#  2. Topological representation
#  3. Metric representation
#  1.2 Map of the environment
#  1.3 Map of the environment
#  Question 1: Type of representation
#  Question 2: SLAM
#
# 3.2 Mapping with Turtlebot
#  1. Turtlebot
#  Question 1: Laser Scan for gmapping
# ```

# %% [markdown]
# ## **1.1 Previous	ROS	achievements**
#
#
# We	managed	to	move	the	Turtlebot	using:
#
# 1. Teleoperation
#
# 2. Shell	commands
#
# 3. A	script

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## **1.2 New	ROS	challenge**
#
# * Navigate	autonomously from	starting	**point	A** to **final	goal B**	given	a	map	of	the	environment.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # **2. What is necessary for navigation?**

# %% [markdown]
# In this lecture, we will look at what is actually required in order to be able to navigate.

# %% [markdown]
# ## **2.1 What	do	we	need	to	navigate?**
#
#
# * Navigation	is	not	just	for	robots !
#
# * Assume	we’re	pirates,	and	we’re	 looking	for	a	treasure.
#
# * We	have	a	crew,	a	ship,	and	a	parrot.

# %% [markdown]
# ## **2.2 What	do	we	need	to	find	a	treasure?**

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# * Sometimes the safest route will be chosen, other times the fastest.

# %% [markdown]
# ## `Question 1:` Element of Navigation ?
#
# * Which element of navigation for a robot corresponds to your location on your treasure map?.

# %% [markdown]
# ```
# 1. A map of the environment
#
# 2. Localization
#
# 3. Path planning
#
# 4.Obstacle avoidance
# ```

# %% [markdown]
# **`Correct:`** This is what corresponds to your **location on the map.**

# %% [markdown]
# # **3. Mapping**
#
# ## **3.1 Mapping theory**
#
# *  What kinds of maps are there?
#
# * And which maps are most useful, in which situations?

# %% [markdown]
# ## **1. Map	of	the	environment**
#
#
# * A	**map**	is	mandatory	for	navigation.
#
#
# * How	to	get	a	map?
#
#  1. Use	a	pre-existing	map

# %% [markdown]
# **Amsterdam	metro	map**

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## **2. Topological	representation**

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## **3. Metric	representation**

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## **1.2 Map	of	the	environment**
#
# * A	**map**	is	mandatory	for	navigation
#
# * How	to	get	a	map?
#
#  1. Use	a	pre-existing	map
#
#  2. Built	by	the	robot	itself	during	a	mapping	process

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## **1.3 Map	of	the	environment**
#
#
# * A	map	is	mandatory	for	navigation
#
# * How	to	get	a	map?
#
#  1. Use	a	pre-existing	map
#
#  2. Built	by	the	robot	itself	during	a	mapping	process
#
#   *  This	process	is	called	SLAM:
#
#   * Simultaneous	Localization	and	Mapping

# %% [markdown]
# ## **`Question 1:`Type of representation**
#
# * When using the metro, what type of representation is the map likely to have?
#
#
# ```
# 1. A metric representation
#
# 2. A topological representation
# ```
#
# * **Ans :** A topological representation

# %% [markdown]
# ## **`Question 2:`SLAM**
#
# * Which two elements are used for SLAM?
#
# ```
# 1. Localization
#
# 2. Path planning to a goal
#
# 3. Mapping
# ```
#
# * **Ans :** 1 and 2

# %% [markdown]
# # **3.2 Mapping with Turtlebot**

# %% [markdown]
# ## **1. Turtlebot**
#
# * The	Turtlebot	uses	a	SLAM	implementation	called	`‘gmapping’	`
#
# * It	gathers	information	about	the	environment	using	**laser	scanning**.
#
# * Data	from	the	laser	scan	is	used	to	build	the	**map**.

# %% [markdown]
# ## **`Question 1:` Laser Scan for gmapping**
#
# * What are these laser scanners used for?
#
# ```
# 1. They are used to measure how much the robot has traveled
#
# 2. They are used to measure where objects are in the environment
#
# 3. They are used to ensure that the robot's pose is as intended
# ```
#
# * **Ans :** 2.
